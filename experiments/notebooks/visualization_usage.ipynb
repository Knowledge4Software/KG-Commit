# %% [markdown]
# # KG-Commit Visualization Module Usage Guide
#
# This notebook demonstrates how to visualize results and timelines.

# %%
import sys
import os
sys.path.append(os.path.join(os.getcwd(), '..', '..'))

from kg_commit.visualization.plots import SimplePlotter
from kg_commit.visualization.timeline_diz import SimpleTimelineVisualizer

# %% [markdown]
# ## Plotting Metrics

# %%
# Create plotter
plotter = SimplePlotter()

# Example results
results = [
    {"accuracy": 0.7, "precision": 0.6},
    {"accuracy": 0.8, "precision": 0.7},
    {"accuracy": 0.85, "precision": 0.75}
]

# Plot over time
plotter.plot_over_time(results)
print("Plotted metrics over time")
# Out:
# Plotted metrics over time

# %% [markdown]
# ## Timeline Visualization

# %%
# Create timeline visualizer
timeline_viz = SimpleTimelineVisualizer()

# Example windows and predictions
# Note: In practice, use actual Window objects
windows = []  # List of Window
predictions = []  # List of prediction arrays

# Plot timeline (would show plot if data provided)
# timeline_viz.plot(windows, predictions)
print("Timeline visualizer created")
# Out:
# Timeline visualizer created
