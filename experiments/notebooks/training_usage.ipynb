# %% [markdown]
# # KG-Commit Training Module Usage Guide
#
# This notebook demonstrates how to train models using trainers.

# %%
import sys
import os
sys.path.append(os.path.join(os.getcwd(), '..', '..'))

from kg_commit.training.trainer import Trainer
from kg_commit.training.incremental_trainer import IncrementalTrainer
from kg_commit.model.online_model import OnlineModel
from kg_commit.data.preprocess import SimplePreprocessor
from kg_commit.evaluation.evaluator import Evaluator

# %% [markdown]
# ## Batch Training

# %%
# Create model and trainer
model = OnlineModel(classes=[0, 1])
trainer = Trainer(model)

# Note: For actual training:
# trainer.train(train_windows)
print("Batch trainer created")
# Out:
# Batch trainer created

# %% [markdown]
# ## Incremental Training

# %%
# Create incremental trainer
preprocessor = SimplePreprocessor()
evaluator = Evaluator()
incremental_trainer = IncrementalTrainer(
    model=model,
    preprocessor=preprocessor,
    evaluator=evaluator
)

# Note: For actual training:
# for window, preds in incremental_trainer.run(stream):
#     pass
print("Incremental trainer created")
# Out:
# Incremental trainer created
